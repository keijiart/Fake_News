# %%
import pandas as pd
import numpy as np

# %%
news = pd.read_csv('news.csv')
fake = pd.read_csv('Fake_x.csv')
true = pd.read_csv('True_x.csv')

# %%
news.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
news['label'] = news['label'].map({'FAKE':0, 'REAL':1}).astype(int)
news.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text  label
# 0  Daniel Greenfield, a Shillman Journalism Fello...      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2  U.S. Secretary of State John F. Kerry said Mon...      1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 4  It's primary day in New York and front-runners...      1

# %%
news.rename(columns={'label': 'class'}, inplace=True)
news.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text  class
# 0  Daniel Greenfield, a Shillman Journalism Fello...      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2  U.S. Secretary of State John F. Kerry said Mon...      1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 4  It's primary day in New York and front-runners...      1

# %%
news = news.drop(['Unnamed: 0'], axis=1)
news.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text  class
# 0  Daniel Greenfield, a Shillman Journalism Fello...      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2  U.S. Secretary of State John F. Kerry said Mon...      1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 4  It's primary day in New York and front-runners...      1

# %%
fake_news = news[news['class'] == 0]
fake_news
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 3     Bernie supporters on Twitter erupt in anger ag...
# 5                                           Tehran, USA
# 6     Girl Horrified At What She Watches Boyfriend D...
# ...                                                 ...
# 6326  DOJ COMPLAINT: Comey Under Fire Over Partisan ...
# 6328  Radio Derb Is On The Air–Leonardo And Brazil’s...
# 6329  Assange claims ‘crazed’ Clinton campaign tried...
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332  Anti-Trump Protesters Are Tools of the Oligarc...
#
#                                                    text  class
# 0     Daniel Greenfield, a Shillman Journalism Fello...      0
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 5       \nI’m not an immigrant, but my grandparents ...      0
# 6     Share This Baylee Luciani (left), Screenshot o...      0
# ...                                                 ...    ...
# 6326  DOJ COMPLAINT: Comey Under Fire Over Partisan ...      0
# 6328                                                         0
# 6329  Julian Assange has claimed the Hillary Clinton...      0
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...      0
# 6332   Anti-Trump Protesters Are Tools of the Oligar...      0
#
# [3164 rows x 3 columns]

# %%
true_news = news[news['class'] == 1]
true_news
# Out:
#                                                   title  \
# 2           Kerry to go to Paris in gesture of sympathy
# 4      The Battle of New York: Why This Primary Matters
# 7                     ‘Britain’s Schindler’ Dies at 106
# 8     Fact check: Trump and Clinton at the 'commande...
# 9     Iran reportedly makes new push for uranium con...
# ...                                                 ...
# 6324  Alabama Lawmaker: Same-Sex Couples Don’t Deser...
# 6327  GOP Senator David Perdue Jokes About Praying f...
# 6330  State Department says it can't find emails fro...
# 6333  In Ethiopia, Obama seeks progress on peace, se...
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text  class
# 2     U.S. Secretary of State John F. Kerry said Mon...      1
# 4     It's primary day in New York and front-runners...      1
# 7     A Czech stockbroker who saved more than 650 Je...      1
# 8     Hillary Clinton and Donald Trump made some ina...      1
# 9     Iranian negotiators reportedly have made a las...      1
# ...                                                 ...    ...
# 6324  Most conservatives who oppose marriage equalit...      1
# 6327  The freshman senator from Georgia quoted scrip...      1
# 6330  The State Department told the Republican Natio...      1
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...      1
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...      1
#
# [3171 rows x 3 columns]

# %%
fake_marge = pd.concat([fake_news, fake], axis=0)
fake_marge = fake_marge.sample(frac = 1)
fake_marge.reset_index(inplace = True)
fake_marge.drop(["index"], axis = 1, inplace = True)
fake_marge['class'] = 0
fake_marge
# Out:
#                                                    title  \
# 0      Baby Bonds: A Plan for Black/White Wealth Equa...
# 1       Why GOP Presidential Candidates Are Angry Ira...
# 2      Close call: Russia-U.S. ‘near-miss’ problem mo...
# 3      MOST AWKARD MOMENT EVER: 6 Months After Trump ...
# 4       BREAKING: Russian Officials Celebrate Rex Til...
# ...                                                  ...
# 26640  WATCH MAJOR MOMENT President-elect Trump And E...
# 26641  BREAKING: YOU’RE FIRED! FBI DIRECTOR JAMES COM...
# 26642  DEPARTMENT STORE MANNEQUINS Changed to Give Na...
# 26643  CATHOLIC PARTIAL BIRTH-ABORTION SUPPORTING DEM...
# 26644   Maddow Compares Trump To 1968 Racist Candidat...
#
#                                                     text  class    subject  \
# 0      by Yves Smith \nYves here. I strongly suspect ...      0        NaN
# 1      The release of Americans being held prisoner i...      0       News
# 2      Print \nIt looks like the vaunted air space co...      0        NaN
# 3      A painfully awkward and heartbreaking moment f...      0   politics
# 4      Quid pro quo in the Trump/Russia situation is ...      0       News
# ...                                                  ...    ...        ...
# 26640                                                         0   politics
# 26641  Wow! This is clearly something the White House...      0   politics
# 26642  Is this a case of the left protesting again by...      0   politics
# 26643  He did the same thing at Obama s inauguration ...      0  left-news
# 26644  Some political pundits have been unable to des...      0       News
#
#                     date
# 0                    NaN
# 1       January 16, 2016
# 2                    NaN
# 3           Dec 21, 2015
# 4      December 14, 2016
# ...                  ...
# 26640       Jan 19, 2017
# 26641        May 9, 2017
# 26642       Aug 15, 2017
# 26643       Sep 26, 2015
# 26644    January 6, 2016
#
# [26645 rows x 5 columns]

# %%
true_marge = pd.concat([true_news, true], axis=0)
true_marge = true_marge.sample(frac = 1)
true_marge.reset_index(inplace = True)
true_marge.drop(["index"], axis = 1, inplace = True)
true_marge['class'] = 1
true_marge.head()
# Out:
#                                                title  \
# 0  Trump to meet scandal-hit Malaysian leader in ...
# 1  'One China' principle must be maintained, Chin...
# 2  UK says has constructive relationship with Ire...
# 3  U.S. plans to admit maximum 45,000 refugees in...
# 4  Afghan suspect arrested in Germany over migran...
#
#                                                 text  class       subject  \
# 0  WASHINGTON/KUALA LUMPUR (Reuters) - President ...      1  politicsNews
# 1  BEIJING (Reuters) - The  One China  principle ...      1     worldnews
# 2  LONDON (Reuters) - Britain has a constructive ...      1     worldnews
# 3  WASHINGTON (Reuters) - The Trump administratio...      1  politicsNews
# 4  BERLIN (Reuters) - German police on Tuesday ar...      1     worldnews
#
#                   date
# 0     August 23, 2017
# 1    October 18, 2017
# 2   November 24, 2017
# 3  September 27, 2017
# 4    December 5, 2017

# %%
# fake_marge.to_csv('Fake1.csv', index=False)

# %%
# true_marge.to_csv('true1.csv', index=False)

# %%
fake_tail = fake_marge.tail(50)

# %%
true_tail = true_marge.tail(50)

# %%
fake_true = pd.concat([true_tail, fake_tail], axis=0)
fake_true
# Out:
#                                                    title  \
# 24538  New York probing Trump's closing of Trump Towe...
# 24539  The big problem Obama's free community college...
# 24540  Obamacare Enrollments Hit Nearly 12 Million, T...
# 24541  Two Republican senators blast Trump as party f...
# 24542  German officials receive threatening letters, ...
# ...                                                  ...
# 26640  WATCH MAJOR MOMENT President-elect Trump And E...
# 26641  BREAKING: YOU’RE FIRED! FBI DIRECTOR JAMES COM...
# 26642  DEPARTMENT STORE MANNEQUINS Changed to Give Na...
# 26643  CATHOLIC PARTIAL BIRTH-ABORTION SUPPORTING DEM...
# 26644   Maddow Compares Trump To 1968 Racist Candidat...
#
#                                                     text  class       subject  \
# 24538   (This May 31 story corrects atrium’s opening ...      1  politicsNews
# 24539  When President Obama called for two years of f...      1           NaN
# 24540  More than half of these enrollees are new to t...      1           NaN
# 24541  WASHINGTON (Reuters) - Tensions among Republic...      1  politicsNews
# 24542  Berlin (Reuters) - Five top German politicians...      1     worldnews
# ...                                                  ...    ...           ...
# 26640                                                         0      politics
# 26641  Wow! This is clearly something the White House...      0      politics
# 26642  Is this a case of the left protesting again by...      0      politics
# 26643  He did the same thing at Obama s inauguration ...      0     left-news
# 26644  Some political pundits have been unable to des...      0          News
#
#                       date
# 24538        May 31, 2016
# 24539                  NaN
# 24540                  NaN
# 24541    October 24, 2017
# 24542  September 21, 2017
# ...                    ...
# 26640         Jan 19, 2017
# 26641          May 9, 2017
# 26642         Aug 15, 2017
# 26643         Sep 26, 2015
# 26644      January 6, 2016
#
# [100 rows x 5 columns]

# %%
fake_true = fake_true.sample(frac = 1)
fake_true.reset_index(inplace = True)
fake_true.drop(["index"], axis = 1, inplace = True)
fake_true.head()
# Out:
#                                                title  \
# 0  Kazakh leader tells cabinet: Make state firms ...
# 1  Obamacare Enrollments Hit Nearly 12 Million, T...
# 2  Who rules the world? America is no longer the ...
# 3  MILLENNIAL Drops Awesome TRUTH BOMB On Her Gen...
# 4  European Union asks Obama to stop 9/11 Saudi bill
#
#                                                 text  class       subject  \
# 0  ASTANA (Reuters) - Kazakh President Nursultan ...      1     worldnews
# 1  More than half of these enrollees are new to t...      1           NaN
# 2  When we ask “who rules the world?” we commonly...      1           NaN
# 3  One millennial is 100% FED Up! with her genera...      0      politics
# 4  WASHINGTON (Reuters) - The European Union on W...      1  politicsNews
#
#                   date
# 0    December 6, 2017
# 1                  NaN
# 2                  NaN
# 3         Apr 28, 2016
# 4  September 21, 2016

# %%
# fake_true.to_csv('News_test.csv', index=False)

# %%
fake_marge.drop(fake_marge.index[-50:-1])
# Out:
#                                                    title  \
# 0      Baby Bonds: A Plan for Black/White Wealth Equa...
# 1       Why GOP Presidential Candidates Are Angry Ira...
# 2      Close call: Russia-U.S. ‘near-miss’ problem mo...
# 3      MOST AWKARD MOMENT EVER: 6 Months After Trump ...
# 4       BREAKING: Russian Officials Celebrate Rex Til...
# ...                                                  ...
# 26591   Arizona GOP Passes Bill To Punish Cities With...
# 26592  OBAMA’S OPEN BORDERS: ILLEGAL ALIEN DEPORTED 1...
# 26593   Bill O’Reilly’s Goon Gets Schooled By College...
# 26594  Another Black Swan Hits the U.S. Presidential ...
# 26644   Maddow Compares Trump To 1968 Racist Candidat...
#
#                                                     text  class   subject  \
# 0      by Yves Smith \nYves here. I strongly suspect ...      0       NaN
# 1      The release of Americans being held prisoner i...      0      News
# 2      Print \nIt looks like the vaunted air space co...      0       NaN
# 3      A painfully awkward and heartbreaking moment f...      0  politics
# 4      Quid pro quo in the Trump/Russia situation is ...      0      News
# ...                                                  ...    ...       ...
# 26591  If cities want to try and help their workers g...      0      News
# 26592  He was just looking to the jobs most Americans...      0  politics
# 26593  Bill O Reilly has a segment of his show in whi...      0      News
# 26594  at 1:43 pm 3 Comments \nBy now, everyone on pl...      0       NaN
# 26644  Some political pundits have been unable to des...      0      News
#
#                     date
# 0                    NaN
# 1       January 16, 2016
# 2                    NaN
# 3           Dec 21, 2015
# 4      December 14, 2016
# ...                  ...
# 26591     March 21, 2016
# 26592       Aug 15, 2015
# 26593      April 9, 2016
# 26594                NaN
# 26644    January 6, 2016
#
# [26596 rows x 5 columns]

# %%
true_marge.drop(true_marge.index[-50:-1])
# Out:
#                                                    title  \
# 0      Trump to meet scandal-hit Malaysian leader in ...
# 1      'One China' principle must be maintained, Chin...
# 2      UK says has constructive relationship with Ire...
# 3      U.S. plans to admit maximum 45,000 refugees in...
# 4      Afghan suspect arrested in Germany over migran...
# ...                                                  ...
# 24534  Irish PM not optimistic Brexit talks will move...
# 24535  Senators seek to block $1.15 billion U.S. arms...
# 24536  Arkansas attorney general says open to working...
# 24537  After Brexit, UK aims for trade deal with EU t...
# 24587  Obama says Islamic State fight far from 'World...
#
#                                                     text  class       subject  \
# 0      WASHINGTON/KUALA LUMPUR (Reuters) - President ...      1  politicsNews
# 1      BEIJING (Reuters) - The  One China  principle ...      1     worldnews
# 2      LONDON (Reuters) - Britain has a constructive ...      1     worldnews
# 3      WASHINGTON (Reuters) - The Trump administratio...      1  politicsNews
# 4      BERLIN (Reuters) - German police on Tuesday ar...      1     worldnews
# ...                                                  ...    ...           ...
# 24534  CLONMEL, Ireland (Reuters) - Irish Prime Minis...      1     worldnews
# 24535  WASHINGTON (Reuters) - Four U.S. senators intr...      1  politicsNews
# 24536  (Reuters) - Arkansas Attorney General Leslie R...      1  politicsNews
# 24537  LONDON (Reuters) - Britain is aiming to secure...      1     worldnews
# 24587  WASHINGTON (Reuters) - President Barack Obama ...      1  politicsNews
#
#                       date
# 0         August 23, 2017
# 1        October 18, 2017
# 2       November 24, 2017
# 3      September 27, 2017
# 4        December 5, 2017
# ...                    ...
# 24534  September 15, 2017
# 24535   September 8, 2016
# 24536   November 17, 2016
# 24537   December 10, 2017
# 24587    January 13, 2016
#
# [24539 rows x 5 columns]

# %%
#true_marge.to_csv('True_final.csv', index=False)

# %%
#fake_marge.to_csv('Fake_final.csv', index=False)
