# %%
import pandas as pd
import numpy as np

# %%
news = pd.read_csv('news_y.csv')
fake = pd.read_csv('Fake_y.csv')
true = pd.read_csv('True_y.csv')

# %%
news.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
news['label'] = news['label'].map({'FAKE':0, 'REAL':1}).astype(int)
news.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text  label
# 0  Daniel Greenfield, a Shillman Journalism Fello...      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2  U.S. Secretary of State John F. Kerry said Mon...      1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 4  It's primary day in New York and front-runners...      1

# %%
news.rename(columns={'label': 'class'}, inplace=True)
news.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text  class
# 0  Daniel Greenfield, a Shillman Journalism Fello...      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2  U.S. Secretary of State John F. Kerry said Mon...      1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 4  It's primary day in New York and front-runners...      1

# %%
news = news.drop(['Unnamed: 0'], axis=1)
news.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text  class
# 0  Daniel Greenfield, a Shillman Journalism Fello...      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2  U.S. Secretary of State John F. Kerry said Mon...      1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 4  It's primary day in New York and front-runners...      1

# %% [markdown]
# # SEPARAMOS LOS FAKES AND TRUES DE NEWS DB

# %%
fake_news = news[news['class'] == 0]
fake_news
# Out:
#                                                   title  \
# 0                          You Can Smell Hillary’s Fear
# 1     Watch The Exact Moment Paul Ryan Committed Pol...
# 3     Bernie supporters on Twitter erupt in anger ag...
# 5                                           Tehran, USA
# 6     Girl Horrified At What She Watches Boyfriend D...
# ...                                                 ...
# 6326  DOJ COMPLAINT: Comey Under Fire Over Partisan ...
# 6328  Radio Derb Is On The Air–Leonardo And Brazil’s...
# 6329  Assange claims ‘crazed’ Clinton campaign tried...
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332  Anti-Trump Protesters Are Tools of the Oligarc...
#
#                                                    text  class
# 0     Daniel Greenfield, a Shillman Journalism Fello...      0
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 5       \nI’m not an immigrant, but my grandparents ...      0
# 6     Share This Baylee Luciani (left), Screenshot o...      0
# ...                                                 ...    ...
# 6326  DOJ COMPLAINT: Comey Under Fire Over Partisan ...      0
# 6328                                                         0
# 6329  Julian Assange has claimed the Hillary Clinton...      0
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...      0
# 6332   Anti-Trump Protesters Are Tools of the Oligar...      0
#
# [3164 rows x 3 columns]

# %%
true_news = news[news['class'] == 1]
true_news
# Out:
#                                                   title  \
# 2           Kerry to go to Paris in gesture of sympathy
# 4      The Battle of New York: Why This Primary Matters
# 7                     ‘Britain’s Schindler’ Dies at 106
# 8     Fact check: Trump and Clinton at the 'commande...
# 9     Iran reportedly makes new push for uranium con...
# ...                                                 ...
# 6324  Alabama Lawmaker: Same-Sex Couples Don’t Deser...
# 6327  GOP Senator David Perdue Jokes About Praying f...
# 6330  State Department says it can't find emails fro...
# 6333  In Ethiopia, Obama seeks progress on peace, se...
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text  class
# 2     U.S. Secretary of State John F. Kerry said Mon...      1
# 4     It's primary day in New York and front-runners...      1
# 7     A Czech stockbroker who saved more than 650 Je...      1
# 8     Hillary Clinton and Donald Trump made some ina...      1
# 9     Iranian negotiators reportedly have made a las...      1
# ...                                                 ...    ...
# 6324  Most conservatives who oppose marriage equalit...      1
# 6327  The freshman senator from Georgia quoted scrip...      1
# 6330  The State Department told the Republican Natio...      1
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...      1
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...      1
#
# [3171 rows x 3 columns]

# %% [markdown]
# # MEZCLAMOS

# %%
fake_marge = pd.concat([fake_news, fake], axis=0)
fake_marge = fake_marge.sample(frac = 1)
fake_marge.reset_index(inplace = True)
fake_marge.drop(["index"], axis = 1, inplace = True)
fake_marge['class'] = 0
fake_marge
# Out:
#                                                    title  \
# 0       Cops In Republican Senate Office Violently As...
# 1      CNN’s Don Lemon Tries to Downplay Horrific ‘An...
# 2       Katrina Pierson Just Blamed Hillary Clinton F...
# 3       Chris Matthews Stuns Colleagues By Telling Th...
# 4      PARKS and REC and JIMMY FALLON Writer Thinks T...
# ...                                                  ...
# 29804   WATCH: Republican Strategist BLASTS ‘Lawless’...
# 29805  BREAKING: Mexico’s President Cancels Visit Wit...
# 29806   Snowflake Trump Makes His Staff Create A Dail...
# 29807   Eric Trump Gives DUMBEST Defense For His Brot...
# 29808  OBAMA PRESSURED U.S. SHOE COMPANY To Keep Thei...
#
#                                                     text  class    subject  \
# 0      A group of disabled Americans protesting the S...      0       News
# 1      In case you missed it, CNN anchor Don Lemon we...      0    US_News
# 2      Following the presidential debate, Donald Trum...      0       News
# 3      Ted Cruz is horrible. According to former clas...      0       News
# 4       When they go low we go high.    Michelle Obam...      0  left-news
# ...                                                  ...    ...        ...
# 29804  Democrats and Republicans don t agree on a lot...      0       News
# 29805  On March 31, 2015 Sergeant Andrew Tahmooressi ...      0  left-news
# 29806  A couple of weeks ago, Donald Trump held his f...      0       News
# 29807  The White House is getting really nervous toda...      0       News
# 29808  Of course, putting America first is a totally ...      0  left-news
#
#                      date
# 0           June 26, 2017
# 1         January 6, 2017
# 2      September 27, 2016
# 3       February 10, 2016
# 4             Oct 1, 2017
# ...                   ...
# 29804       July 22, 2017
# 29805        Jan 26, 2017
# 29806       June 29, 2017
# 29807       July 11, 2017
# 29808        Apr 14, 2016
#
# [29809 rows x 5 columns]

# %%
#fake_marge.drop(["class"], axis = 1, inplace = True)
#fake_marge

# %%
true_marge = pd.concat([true_news, true], axis=0)
true_marge = true_marge.sample(frac = 1)
true_marge.reset_index(inplace = True)
true_marge.drop(["index"], axis = 1, inplace = True)
true_marge['class'] = 1
true_marge
# Out:
#                                                    title  \
# 0      Energy Secretary Perry cancels Kazakhstan visi...
# 1      Dozens killed, wounded by car bomb in Afghan p...
# 2      Moscow to cut dependence on U.S. payment syste...
# 3      In Syria, Russia securing position as Assad pr...
# 4      Coca, trafficking greatest threats to Colombia...
# ...                                                  ...
# 27754  How Tim Scott chose to endorse Marco Rubio for...
# 27755  Finnish president says joining NATO would requ...
# 27756  Factbox: Where key U.S. Republican senators st...
# 27757  New York, other states challenge Trump over cl...
# 27758  Philippine drugs board chief quits after contr...
#
#                                                     text  class       subject  \
# 0      ALMATY (Reuters) - United States Energy Secret...      1  politicsNews
# 1      KABUL (Reuters) - As many as 13 people, includ...      1     worldnews
# 2      MOSCOW (Reuters) - Russia will speed up work o...      1  politicsNews
# 3      BEIRUT (Reuters) - With the map of Syria s con...      1     worldnews
# 4      BOGOTA (Reuters) - A peace deal between Colomb...      1     worldnews
# ...                                                  ...    ...           ...
# 27754  Like a modern day Ben Franklin, Sen. Tim Scott...      1           NaN
# 27755  HELSINKI (Reuters) - Any move by Finland to jo...      1     worldnews
# 27756  WASHINGTON (Reuters) - U.S. Senate Republicans...      1  politicsNews
# 27757  WASHINGTON (Reuters) - A coalition of 17 U.S. ...      1  politicsNews
# 27758  MANILA (Reuters) - The head of the Philippines...      1     worldnews
#
#                      date
# 0        August 28, 2017
# 1        August 27, 2017
# 2         August 7, 2017
# 3      December 15, 2017
# 4       October 13, 2017
# ...                   ...
# 27754                 NaN
# 27755   October 30, 2017
# 27756      June 22, 2017
# 27757      April 5, 2017
# 27758   November 7, 2017
#
# [27759 rows x 5 columns]

# %%
fake_tail = fake_marge.tail(50)

# %%
true_tail = true_marge.tail(50)

# %%
fake_true = pd.concat([true_tail, fake_tail], axis=0)
fake_true = fake_true.sample(frac = 1)
fake_true.reset_index(inplace = True)
fake_true.drop(["index"], axis = 1, inplace = True)
fake_true
# Out:
#                                                 title  \
# 0                                          ‘We Caved’
# 1   Zimbabwe court postpones U.S. citizen's subver...
# 2   Congress sends White House repeal of broadband...
# 3   Poland's stance on migrants unchanged despite ...
# 4   Putin critic Navalny calls election boycott ra...
# ..                                                ...
# 95  Finnish president says joining NATO would requ...
# 96  Head of UK's anti-Brexit party appeals for hel...
# 97  Hezbollah emerges a winner from Mideast turmoi...
# 98  Say What?! FBI Never Destroyed Laptops of Clin...
# 99  Kansas House fails in attempt to override Medi...
#
#                                                  text  class       subject  \
# 0   On a late July day this past summer, a roar fi...      1           NaN
# 1   HARARE (Reuters) - A Zimbabwean court has post...      1     worldnews
# 2   WASHINGTON (Reuters) - The U.S. House voted on...      1  politicsNews
# 3   KRYNICA ZDROJ, Poland (Reuters) - Poland will ...      1     worldnews
# 4   MOSCOW (Reuters) - Opposition leader Alexei Na...      1     worldnews
# ..                                                ...    ...           ...
# 95  HELSINKI (Reuters) - Any move by Finland to jo...      1     worldnews
# 96  LONDON (Reuters) - Calling himself a  proud sa...      1     worldnews
# 97  BEIRUT (Reuters) - When Iran declared victory ...      1     worldnews
# 98  0 comments \nThis is just too rich! The FBI ag...      0           NaN
# 99  (Reuters) - Lawmakers in Kansas on Monday fail...      1  politicsNews
#
#                    date
# 0                   NaN
# 1     December 8, 2017
# 2       March 28, 2017
# 3    September 6, 2017
# 4    December 27, 2017
# ..                  ...
# 95    October 30, 2017
# 96  September 18, 2017
# 97   November 30, 2017
# 98                  NaN
# 99       April 3, 2017
#
# [100 rows x 5 columns]

# %%
fakemarge= fake_marge[:-50]
fakemarge
# Out:
#                                                    title  \
# 0       Cops In Republican Senate Office Violently As...
# 1      CNN’s Don Lemon Tries to Downplay Horrific ‘An...
# 2       Katrina Pierson Just Blamed Hillary Clinton F...
# 3       Chris Matthews Stuns Colleagues By Telling Th...
# 4      PARKS and REC and JIMMY FALLON Writer Thinks T...
# ...                                                  ...
# 29754  IS ROMNEY SERIOUSLY THINKING ABOUT ENTERING TH...
# 29755  Episode #159 – SUNDAY WIRE: ‘Tick-Tock USA’ wi...
# 29756  GROSS! MADONNA OFFERS UP Sexual Services If Yo...
# 29757   House Dem Wants GOP On Record: Stop Gov’t Spe...
# 29758  Clinton campaign blames FBI director for loss ...
#
#                                                     text  class    subject  \
# 0      A group of disabled Americans protesting the S...      0       News
# 1      In case you missed it, CNN anchor Don Lemon we...      0    US_News
# 2      Following the presidential debate, Donald Trum...      0       News
# 3      Ted Cruz is horrible. According to former clas...      0       News
# 4       When they go low we go high.    Michelle Obam...      0  left-news
# ...                                                  ...    ...        ...
# 29754  As if this presidential race couldn t get any ...      0   politics
# 29755   Episode #159 of SUNDAY WIRE SHOW resumes this...      0    US_News
# 29756  [Warning: Story contains graphic language]Pop ...      0   politics
# 29757  Early next month, the GOP-controlled House of ...      0       News
# 29758  Politics FBI Director James Comey (AFP file ph...      0        NaN
#
#                      date
# 0           June 26, 2017
# 1         January 6, 2017
# 2      September 27, 2016
# 3       February 10, 2016
# 4             Oct 1, 2017
# ...                   ...
# 29754        Aug 24, 2015
# 29755    November 6, 2016
# 29756        Oct 19, 2016
# 29757     August 24, 2017
# 29758                 NaN
#
# [29759 rows x 5 columns]

# %%
fakemarge.drop(["class"], axis = 1, inplace = True)
# Out:
# /Users/keijiarostegui/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
truemerge = true_marge[:-50]
truemerge
# Out:
#                                                    title  \
# 0      Energy Secretary Perry cancels Kazakhstan visi...
# 1      Dozens killed, wounded by car bomb in Afghan p...
# 2      Moscow to cut dependence on U.S. payment syste...
# 3      In Syria, Russia securing position as Assad pr...
# 4      Coca, trafficking greatest threats to Colombia...
# ...                                                  ...
# 27704  Turkey will take its own security measures aft...
# 27705  China's Xi says can thwart Taiwan independence...
# 27706  Trump rejects criticism, vents at news media i...
# 27707  Selma 50 years on: John Lewis's recalls the march
# 27708  Afghan president 'grateful' for Trump's commit...
#
#                                                     text  class       subject  \
# 0      ALMATY (Reuters) - United States Energy Secret...      1  politicsNews
# 1      KABUL (Reuters) - As many as 13 people, includ...      1     worldnews
# 2      MOSCOW (Reuters) - Russia will speed up work o...      1  politicsNews
# 3      BEIRUT (Reuters) - With the map of Syria s con...      1     worldnews
# 4      BOGOTA (Reuters) - A peace deal between Colomb...      1     worldnews
# ...                                                  ...    ...           ...
# 27704  ANKARA (Reuters) - President Tayyip Erdogan on...      1     worldnews
# 27705  BEIJING/TAIPEI (Reuters) - China has the resol...      1     worldnews
# 27706  WASHINGTON (Reuters) - Republican presidential...      1  politicsNews
# 27707  Watch live coverage of ceremonies in Selma com...      1           NaN
# 27708  KABUL (Reuters) - Afghan leader Ashraf Ghani o...      1  politicsNews
#
#                       date
# 0         August 28, 2017
# 1         August 27, 2017
# 2          August 7, 2017
# 3       December 15, 2017
# 4        October 13, 2017
# ...                    ...
# 27704  September 13, 2017
# 27705    October 18, 2017
# 27706        July 7, 2016
# 27707                  NaN
# 27708     August 22, 2017
#
# [27709 rows x 5 columns]

# %%
truemerge.drop(["class"], axis = 1, inplace = True)
# Out:
# /Users/keijiarostegui/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
truemerge
# Out:
#                                                    title  \
# 0      Energy Secretary Perry cancels Kazakhstan visi...
# 1      Dozens killed, wounded by car bomb in Afghan p...
# 2      Moscow to cut dependence on U.S. payment syste...
# 3      In Syria, Russia securing position as Assad pr...
# 4      Coca, trafficking greatest threats to Colombia...
# ...                                                  ...
# 27704  Turkey will take its own security measures aft...
# 27705  China's Xi says can thwart Taiwan independence...
# 27706  Trump rejects criticism, vents at news media i...
# 27707  Selma 50 years on: John Lewis's recalls the march
# 27708  Afghan president 'grateful' for Trump's commit...
#
#                                                     text       subject  \
# 0      ALMATY (Reuters) - United States Energy Secret...  politicsNews
# 1      KABUL (Reuters) - As many as 13 people, includ...     worldnews
# 2      MOSCOW (Reuters) - Russia will speed up work o...  politicsNews
# 3      BEIRUT (Reuters) - With the map of Syria s con...     worldnews
# 4      BOGOTA (Reuters) - A peace deal between Colomb...     worldnews
# ...                                                  ...           ...
# 27704  ANKARA (Reuters) - President Tayyip Erdogan on...     worldnews
# 27705  BEIJING/TAIPEI (Reuters) - China has the resol...     worldnews
# 27706  WASHINGTON (Reuters) - Republican presidential...  politicsNews
# 27707  Watch live coverage of ceremonies in Selma com...           NaN
# 27708  KABUL (Reuters) - Afghan leader Ashraf Ghani o...  politicsNews
#
#                       date
# 0         August 28, 2017
# 1         August 27, 2017
# 2          August 7, 2017
# 3       December 15, 2017
# 4        October 13, 2017
# ...                    ...
# 27704  September 13, 2017
# 27705    October 18, 2017
# 27706        July 7, 2016
# 27707                  NaN
# 27708     August 22, 2017
#
# [27709 rows x 4 columns]

# %%
#fake_marge.drop(fake_marge.index[-50:])

# %%
#true_marge.drop(true_marge.index[-50:])

# %%
fakemarge.to_csv('Fake_estesi.csv', index=False)

# %%
truemerge.to_csv('True_estesi.csv', index=False)

# %%
fake_true.to_csv('News_test.csv', index=False)
